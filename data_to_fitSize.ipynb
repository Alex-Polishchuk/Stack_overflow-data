# %%
import pandas as pd

# %%
df = pd.read_csv(r"Data\survey_results_public.csv")

# %%
df.head()
# Out:
#     NLC   ASC            Station Fare Zone        Total  Early       \
# 0   750  ABRd         Abbey Road       2/3  1712.734271  154.483201
# 1  1404  ACCr      Acton Central         3  2707.259588  188.391296
# 2   500  ACTu         Acton Town         3  6900.219070  434.466475
# 3  9440  ADSt         Addiscombe         4  1918.500000  166.000000
# 4  9441  ADVt  Addington Village         4  1245.000000  103.000000
#
#     AM Peak      Midday       PM Peak     Evening     ...  0230-0245  \
# 0   463.806778   533.037402   354.662608  140.184088  ...   0.000000
# 1   911.648993   697.202637   646.485216  199.918595  ...   0.000000
# 2  2172.533608  2045.282187  1622.404240  459.327166  ...   0.012508
# 3   520.000000   762.000000   338.500000  104.000000  ...   0.000000
# 4   285.000000   537.000000   242.000000   67.500000  ...   0.000000
#
#    0245-0300  0300-0315  0315-0330  0330-0345  0345-0400  0400-0415  \
# 0    0.00000   0.000000   0.000000   0.000000   0.000000   0.000000
# 1    0.00000   0.000000   0.000000   0.000000   0.000000   0.000000
# 2    0.02639   0.034258   0.081714   0.077062   0.073201   0.058669
# 3    0.00000   0.000000   0.000000   0.000000   0.000000   0.000000
# 4    0.00000   0.000000   0.000000   0.000000   0.000000   0.000000
#
#    0415-0430  0430-0445  0445-0500
# 0   0.000000   0.000000   0.000000
# 1   0.000000   0.000000   0.000000
# 2   5.190521   5.141634   5.141634
# 3   0.000000   0.000000   0.000000
# 4   0.000000   0.000000   0.000000
#
# [5 rows x 107 columns]

# %%
#Drops values which have only null values
df.drop("VHCProfessionalUse", index=1, inplace=True)
df.drop("VHCPersonalUse", index=1, inplace=True)
# Out:
# (466, 107)

# %%
#Need to drop additional columns to fit GitHub column sizes
df.drop("Trans", axis = 1, inplace=True)
df.drop("Survey_Length", axis = 1, inplace=True) 
df.drop("Survey_Ease", axis = 1, inplace=True)
# Out:
# NLC                  750
# ASC                 ABRd
# Station       Abbey Road
# Fare Zone            2/3
# Total        1712.734271
#                 ...
# 0345-0400            0.0
# 0400-0415            0.0
# 0415-0430            0.0
# 0430-0445            0.0
# 0445-0500            0.0
# Name: 0, Length: 107, dtype: object
