# %%
import pandas as pd

# %% [markdown]
# Read the public clean file

# %%
df = pd.read_csv("Data/survey_results_public_clean.csv")

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
#Look at all columns
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %% [markdown]
# Renaming columns for clarity, source: survey_results_schema.xlsx

# %%
#Create 2 dictionaries to have old column name and new column name
rename_dict_knowQ1 = {"Knowledge_1":"InteractOutsideTeam","Knowledge_2":"KnowledgeSiloPrevent","Knowledge_3":"UpToDateOrgInfo"}
rename_dict_knowQ2 = {"Knowledge_4":"FindAnsW/Tools","Knowledge_5":"KnowHowToFindAns","Knowledge_6":"AnsQWhichAlreadyAnsBefore","Knowledge_7":"WaitForAnsRuinW/Flow"}

# %%
#Rename 1st set of columns
df.rename(columns=rename_dict_knowQ1, inplace=True)

# %%
#Rename second set of columns
df.rename(columns=rename_dict_knowQ2, inplace=True)

# %%
#Check that the rename was succesful
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
#creating dicts for renaming frequency and TrueFalse Questions
rename_dict_Freq = {"Frequency_1":"NeedHelpOutsideOfImmediateTeam","Frequency_2":"InteractOutsideOfImmediateTeam","Frequency_3":"KnowledgeSilo"}
rename_dict_TrueFalse = {"TrueFalse_1":"SupportNewHiresOnboarding","TrueFalse_2":"LearnResourcesProvidedByEmp","TrueFalse_3":"GiveTimeToLearnNewSkill"}

# %%
#Actual renaming of columns
df.rename(columns=rename_dict_Freq, inplace=True)
df.rename(columns=rename_dict_TrueFalse, inplace=True)
